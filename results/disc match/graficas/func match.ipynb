# %%
import pandas as pd
import matplotlib
from matplotlib import pyplot as plt
#%matplotlib inline
import seaborn as sns

# %%
path = '/Users/jairoandresarizacastaneda/Desktop/Tesis 1/pruebas/disc match/func match rev1.xlsx'
df = pd.read_excel(path)

# %%
fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(21,7))

bp1, bp = df.boxplot(column=['1000 sensors','2000 sensors'], fontsize = 20,
                return_type="both", patch_artist=True, ax=axs[0])
#bp1.set_title("Functional matching time", fontsize=25)
#bp1.set_xlabel("Sensors number", fontsize=15)
bp1.set_ylabel("Functional matchig time (s)\n", fontsize=25)
[[item.set_linewidth(2) for item in bp[key]] for key in bp.keys()]
[item.set_linewidth(4) for item in bp["medians"]]
bp["boxes"][0].set_color("r")
bp["whiskers"][0].set_color("r")
bp["whiskers"][1].set_color("r")
bp["caps"][0].set_color("r")
bp["caps"][1].set_color("r")

bp["boxes"][1].set_color("b")
bp["whiskers"][2].set_color("b")
bp["whiskers"][3].set_color("b")
bp["caps"][2].set_color("b")
bp["caps"][3].set_color("b")

bp1, bp = df.boxplot(column=['3500 sensors','5000 sensors'], fontsize = 20,
                return_type="both", patch_artist=True, ax=axs[1])
bp1.set_title("Functional matching time\n", fontsize=30)
bp1.set_xlabel("\nSensors number", fontsize=25)
#bp1.set_ylabel("Functional matchig time (s)", fontsize=15)
[[item.set_linewidth(2) for item in bp[key]] for key in bp.keys()]
[item.set_linewidth(4) for item in bp["medians"]]
bp["boxes"][0].set_color("r")
bp["whiskers"][0].set_color("r")
bp["whiskers"][1].set_color("r")
bp["caps"][0].set_color("r")
bp["caps"][1].set_color("r")

bp["boxes"][1].set_color("b")
bp["whiskers"][2].set_color("b")
bp["whiskers"][3].set_color("b")
bp["caps"][2].set_color("b")
bp["caps"][3].set_color("b")

bp1, bp = df.boxplot(column=['7500 sensors','10000 sensors'], fontsize = 20,
                return_type="both", patch_artist=True, ax=axs[2])
#bp1.set_xlabel("Sensors number", fontsize=15)
#bp1.set_ylabel("Functional matchig time (s)", fontsize=15)
[[item.set_linewidth(2) for item in bp[key]] for key in bp.keys()]
[item.set_linewidth(4) for item in bp["medians"]]
bp["boxes"][0].set_color("r")
bp["whiskers"][0].set_color("r")
bp["whiskers"][1].set_color("r")
bp["caps"][0].set_color("r")
bp["caps"][1].set_color("r")

bp["boxes"][1].set_color("b")
bp["whiskers"][2].set_color("b")
bp["whiskers"][3].set_color("b")
bp["caps"][2].set_color("b")
bp["caps"][3].set_color("b")

#plt.tight_layout()
