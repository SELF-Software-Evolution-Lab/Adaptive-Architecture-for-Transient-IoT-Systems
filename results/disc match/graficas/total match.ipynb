# %%
import pandas as pd
import matplotlib
from matplotlib import pyplot as plt
#%matplotlib inline
import seaborn as sns

# %%
path = '/Users/jairoandresarizacastaneda/Desktop/Tesis 1/pruebas/disc match/total matching rev1.xlsx'
df = pd.read_excel(path)

# %%
bp1, bp = df.boxplot(column=['1000 sensors','2000 sensors','3500 sensors','5000 sensors',
                             '7500 sensors','10000 sensors'], 
                figsize =(20,10), fontsize = 15,
                return_type="both", patch_artist=True)
bp1.set_title("Total matching time", fontsize=25)
bp1.set_xlabel("Sensors number", fontsize=15)
bp1.set_ylabel("Total matchig time (s)", fontsize=15)
#[[item.set_linewidth(2) for item in bp[key]] for key in bp.keys()]
#[item.set_linewidth(4) for item in bp["medians"]]
bp["boxes"][2].set_color("r")
bp["whiskers"][4].set_color("r")
bp["whiskers"][5].set_color("r")
bp["caps"][4].set_color("r")
bp["caps"][5].set_color("r")

bp["boxes"][3].set_color("b")
bp["whiskers"][6].set_color("b")
bp["whiskers"][7].set_color("b")
bp["caps"][6].set_color("b")
bp["caps"][7].set_color("b")

bp["boxes"][4].set_color("gray")
bp["whiskers"][8].set_color("gray")
bp["whiskers"][9].set_color("gray")
bp["caps"][8].set_color("gray")
bp["caps"][9].set_color("gray")

bp["boxes"][5].set_color("y")
bp["whiskers"][10].set_color("y")
bp["whiskers"][11].set_color("y")
bp["caps"][10].set_color("y")
bp["caps"][11].set_color("y")
