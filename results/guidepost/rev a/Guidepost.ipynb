# %%
import pandas as pd
import matplotlib
from matplotlib import pyplot as plt
#%matplotlib inline
import seaborn as sns

# %%
path = '/Users/jairoandresarizacastaneda/Desktop/Tesis 1/pruebas/guidepost/guidepost update rev 1.xlsx'
df = pd.read_excel(path)

# %%
bp1, bp = df.boxplot(column=['250 services', '500 services', '750 services', '1000 services'], 
                figsize =(11,11), fontsize = 20,
                return_type="both", patch_artist=True)
bp1.set_title("Guidepost update time\n", fontsize=30)
bp1.set_xlabel("\nGuidepost size", fontsize=25)
bp1.set_ylabel("Guidepost update time (s)\n", fontsize=25)
[[item.set_linewidth(2) for item in bp[key]] for key in bp.keys()]
[item.set_linewidth(4) for item in bp["medians"]]
bp["boxes"][0].set_color("r")
bp["whiskers"][0].set_color("r")
bp["whiskers"][1].set_color("r")
bp["caps"][0].set_color("r")
bp["caps"][1].set_color("r")

bp["boxes"][1].set_color("b")
bp["whiskers"][2].set_color("b")
bp["whiskers"][3].set_color("b")
bp["caps"][2].set_color("b")
bp["caps"][3].set_color("b")

bp["boxes"][2].set_color("gray")
bp["whiskers"][4].set_color("gray")
bp["whiskers"][5].set_color("gray")
bp["caps"][4].set_color("gray")
bp["caps"][5].set_color("gray")

bp["boxes"][3].set_color("y")
bp["whiskers"][6].set_color("y")
bp["whiskers"][7].set_color("y")
bp["caps"][6].set_color("y")
bp["caps"][7].set_color("y")
